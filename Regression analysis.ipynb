# %% [markdown]
# Regression analysis is a way to find the relationship between input and output.
#
# 💡 Example:
#
# You want to know: "If a student studies more, will their marks increase?"
#
# Input: Hours studied
#
# Output: Marks
#
# Regression helps you draw a line like:
# 👉 "More hours = more marks"

# %%
import pandas as pd

# %%
df=pd.read_csv("car data.csv")
df.head(10)
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0           ritz  2014           3.35           5.59       27000    Petrol
# 1            sx4  2013           4.75           9.54       43000    Diesel
# 2           ciaz  2017           7.25           9.85        6900    Petrol
# 3        wagon r  2011           2.85           4.15        5200    Petrol
# 4          swift  2014           4.60           6.87       42450    Diesel
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
# 6           ciaz  2015           6.75           8.12       18796    Petrol
# 7        s cross  2015           6.50           8.61       33429    Diesel
# 8           ciaz  2016           8.75           8.89       20273    Diesel
# 9           ciaz  2015           7.45           8.92       42367    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# ...

# %%
df.drop('Kms_Driven',axis=1,inplace=True)
df.head()
# Out:
#    Car_Name  Year  Selling_Price  Present_Price Fuel_Type Seller_Type  \
# 0      ritz  2014           3.35           5.59    Petrol      Dealer
# 1       sx4  2013           4.75           9.54    Diesel      Dealer
# 2      ciaz  2017           7.25           9.85    Petrol      Dealer
# 3   wagon r  2011           2.85           4.15    Petrol      Dealer
# 4     swift  2014           4.60           6.87    Diesel      Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %% [markdown]
# **linear regression**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('placement.csv')

df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
sns.scatterplot(x='cgpa',y='package',data=df)
plt.show()

# %%
df.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
x=df[['cgpa']]
y=df['package']

# %%
from sklearn.model_selection import  train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train,x_test,y_train,y_test
# Out:
# (     cgpa
#  79   7.18
#  197  7.21
#  38   8.62
#  24   6.53
#  122  5.12
#  ..    ...
#  106  6.13
#  14   7.73
#  92   7.90
#  179  7.14
#  102  5.13
#
#  [160 rows x 1 columns],
#       cgpa
#  95   6.63
#  15   7.25
#  30   7.36
#  158  5.95
#  128  7.93
#  115  8.35
#  69   7.30
#  170  6.22
#  174  7.32
#  45   7.87
#  66   5.11
#  182  5.88
#  165  8.21
#  78   6.59
#  186  7.84
#  177  7.09
#  56   5.84
#  152  7.37
#  82   5.58
#  68   7.56
#  124  6.06
#  16   6.84
#  148  7.57
#  93   6.79
#  65   7.60
#  60   5.61
#  84   4.26
#  67   6.51
#  125  7.33
#  132  5.84
#  9    8.31
#  18   6.94
#  55   8.20
#  75   6.97
#  150  6.30
#  104  7.62
#  135  6.10
#  137  7.14
#  164  9.06
#  76   6.94,
#  79     3.00
#  197    3.24
#  38     4.36
#  24     2.71
#  122    2.01
#         ...
#  106    2.19
#  14     3.42
#  92     4.00
#  179    3.03
#  102    1.37
#  Name: package, Length: 160, dtype: float64,
#  95     2.79
#  15     3.23
#  30     3.26
#  158    3.04
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)  #x_train is input,y_train is output
# Out:
# LinearRegression()

# %%
# Accuracy Score   
lr.score(x_test,y_test)
# Out:
# 0.7730984312051673

# %%
lr.score(x_test,y_test)*100
# Out:
# 77.30984312051673

# %%
# 6.89	3.26

# %%
# now check if i give input so output aproximate is correct
lr.predict([[6.89]])
# Out:
# c:\Users\admin\Documents\PYTHON1.0\venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2.92962016])

# %%
y_prd=lr.predict(x)

# %%
plt.Figure(figsize=(5,4))
sns.scatterplot(x="cgpa",y="package",data=df)
plt.plot(df['cgpa'],y_prd,c='red')
plt.legend(['org data','predict line'])
plt.savefig('predict.jpg')
plt.show()
